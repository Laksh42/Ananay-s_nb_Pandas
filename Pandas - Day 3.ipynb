# %%
import pandas as pd
import numpy as np
s = pd.Series(['Katrina','Raman','Jessica','Albert','1234','Smith'])
s
# Out:
# 0    Katrina
# 1      Raman
# 2    Jessica
# 3     Albert
# 4       1234
# 5      Smith
# dtype: object

# %%
s.str.lower()
# Out:
# 0    katrina
# 1      raman
# 2    jessica
# 3     albert
# 4       1234
# 5      smith
# dtype: object

# %%
s.str.upper()
# Out:
# 0    KATRINA
# 1      RAMAN
# 2    JESSICA
# 3     ALBERT
# 4       1234
# 5      SMITH
# dtype: object

# %%
s.str.len()
# Out:
# 0    7
# 1    5
# 2    7
# 3    6
# 4    4
# 5    5
# dtype: int64

# %%
print(s)
s[s.str.contains('a')]
# Out:
# 0    Katrina
# 1      Raman
# 2    Jessica
# 3     Albert
# 4       1234
# 5      Smith
# dtype: object
# 0    Katrina
# 1      Raman
# 2    Jessica
# dtype: object

# %%
s.str.replace('a','@')
# Out:
# 0    K@trin@
# 1      R@m@n
# 2    Jessic@
# 3     Albert
# 4       1234
# 5      Smith
# dtype: object

# %%
for i in s.str.split():
    print(i[0]+' '+i[0])
# Out:
# Katrina Katrina
# Raman Raman
# Jessica Jessica
# Albert Albert
# 1234 1234
# Smith Smith

# %%
s.str.count('a')
# Out:
# 0    2
# 1    2
# 2    1
# 3    0
# 4    0
# 5    0
# dtype: int64

# %%
s[s.str.startswith('Sm')]
# Out:
# 5    Smith
# dtype: object

# %%
s[s.str.endswith('h')]
# Out:
# 5    Smith
# dtype: object

# %%
s[s.str.find('n')> 0]
# Out:
# 0    Katrina
# 1      Raman
# dtype: object

# %%
s.str.swapcase()
# Out:
# 0    kATRINA
# 1      rAMAN
# 2    jESSICA
# 3     aLBERT
# 4       1234
# 5      sMITH
# dtype: object

# %%
s.str.findall('a')
# Out:
# 0    [a, a]
# 1    [a, a]
# 2       [a]
# 3        []
# 4        []
# 5        []
# dtype: object

# %%
s
# Out:
# 0    Katrina
# 1      Raman
# 2    Jessica
# 3     Albert
# 4       1234
# 5      Smith
# dtype: object

# %%
s.str.isupper()
# Out:
# 0    False
# 1    False
# 2    False
# 3    False
# 4    False
# 5    False
# dtype: bool

# %%
s.str.islower()
# Out:
# 0    False
# 1    False
# 2    False
# 3    False
# 4    False
# 5    False
# dtype: bool

# %%
s[s.str.isnumeric()]
# Out:
# 4    1234
# dtype: object

# %%
import pandas as pd
df1 = pd.DataFrame({
         'id':[1,2,3,4,5],
         'Name': ['Piyush', 'Gautam', 'Garry', 'Abhishek', 'Ankit'],
         'subject_id':['sub1','sub2','sub4','sub6','sub5']})
df2 = pd.DataFrame(
         {'id':[1,2,3,4,5],
         'Name': ['Saurabh', 'Akshay', 'Rajat', 'Ankush', 'Sam'],
         'subject_id':['sub2','sub4','sub3','sub6','sub5']})

# %%
df1
# Out:
#    id      Name subject_id
# 0   1    Piyush       sub1
# 1   2    Gautam       sub2
# 2   3     Garry       sub4
# 3   4  Abhishek       sub6
# 4   5     Ankit       sub5

# %%
df2
# Out:
#    id     Name subject_id
# 0   1  Saurabh       sub2
# 1   2   Akshay       sub4
# 2   3    Rajat       sub3
# 3   4   Ankush       sub6
# 4   5      Sam       sub5

# %%
pd.merge(df1,df2,on='id')
# Out:
#    id    Name_x subject_id_x   Name_y subject_id_y
# 0   1    Piyush         sub1  Saurabh         sub2
# 1   2    Gautam         sub2   Akshay         sub4
# 2   3     Garry         sub4    Rajat         sub3
# 3   4  Abhishek         sub6   Ankush         sub6
# 4   5     Ankit         sub5      Sam         sub5

# %%
pd.merge(df1,df2,on=['id','subject_id'])
# Out:
#    id    Name_x subject_id  Name_y
# 0   4  Abhishek       sub6  Ankush
# 1   5     Ankit       sub5     Sam

# %%
pd.merge(df1,df2,on='subject_id',how='left')
# Out:
#    id_x    Name_x subject_id  id_y   Name_y
# 0     1    Piyush       sub1   NaN      NaN
# 1     2    Gautam       sub2   1.0  Saurabh
# 2     3     Garry       sub4   2.0   Akshay
# 3     4  Abhishek       sub6   4.0   Ankush
# 4     5     Ankit       sub5   5.0      Sam

# %%
pd.merge(df1,df2,on='subject_id',how='right')
# Out:
#    id_x    Name_x subject_id  id_y   Name_y
# 0   2.0    Gautam       sub2     1  Saurabh
# 1   3.0     Garry       sub4     2   Akshay
# 2   4.0  Abhishek       sub6     4   Ankush
# 3   5.0     Ankit       sub5     5      Sam
# 4   NaN       NaN       sub3     3    Rajat

# %%
pd.merge(df1,df2,on='subject_id',how='inner')
# Out:
#    id_x    Name_x subject_id  id_y   Name_y
# 0     2    Gautam       sub2     1  Saurabh
# 1     3     Garry       sub4     2   Akshay
# 2     4  Abhishek       sub6     4   Ankush
# 3     5     Ankit       sub5     5      Sam

# %%
pd.merge(df1,df2,on='subject_id',how='outer')
# Out:
#    id_x    Name_x subject_id  id_y   Name_y
# 0   1.0    Piyush       sub1   NaN      NaN
# 1   2.0    Gautam       sub2   1.0  Saurabh
# 2   3.0     Garry       sub4   2.0   Akshay
# 3   4.0  Abhishek       sub6   4.0   Ankush
# 4   5.0     Ankit       sub5   5.0      Sam
# 5   NaN       NaN       sub3   3.0    Rajat

# %%
df1
# Out:
#    id      Name subject_id
# 0   1    Piyush       sub1
# 1   2    Gautam       sub2
# 2   3     Garry       sub4
# 3   4  Abhishek       sub6
# 4   5     Ankit       sub5

# %%
df2
# Out:
#    id     Name subject_id
# 0   1  Saurabh       sub2
# 1   2   Akshay       sub4
# 2   3    Rajat       sub3
# 3   4   Ankush       sub6
# 4   5      Sam       sub5

# %%
pd.concat([df1,df2],ignore_index=True,axis=0)
# Out:
#    id      Name subject_id
# 0   1    Piyush       sub1
# 1   2    Gautam       sub2
# 2   3     Garry       sub4
# 3   4  Abhishek       sub6
# 4   5     Ankit       sub5
# 5   1   Saurabh       sub2
# 6   2    Akshay       sub4
# 7   3     Rajat       sub3
# 8   4    Ankush       sub6
# 9   5       Sam       sub5

# %%
pd.concat([df1,df2],ignore_index=True,axis=1)
# Out:
#    0         1     2  3        4     5
# 0  1    Piyush  sub1  1  Saurabh  sub2
# 1  2    Gautam  sub2  2   Akshay  sub4
# 2  3     Garry  sub4  3    Rajat  sub3
# 3  4  Abhishek  sub6  4   Ankush  sub6
# 4  5     Ankit  sub5  5      Sam  sub5

# %%
df1
# Out:
#    id      Name subject_id
# 0   1    Piyush       sub1
# 1   2    Gautam       sub2
# 2   3     Garry       sub4
# 3   4  Abhishek       sub6
# 4   5     Ankit       sub5

# %%
df2
# Out:
#    id     Name subject_id
# 0   1  Saurabh       sub2
# 1   2   Akshay       sub4
# 2   3    Rajat       sub3
# 3   4   Ankush       sub6
# 4   5      Sam       sub5

# %%
df1.append(df2)
# Out:
#    id      Name subject_id
# 0   1    Piyush       sub1
# 1   2    Gautam       sub2
# 2   3     Garry       sub4
# 3   4  Abhishek       sub6
# 4   5     Ankit       sub5
# 0   1   Saurabh       sub2
# 1   2    Akshay       sub4
# 2   3     Rajat       sub3
# 3   4    Ankush       sub6
# 4   5       Sam       sub5

# %%
df1
# Out:
#    id      Name subject_id
# 0   1    Piyush       sub1
# 1   2    Gautam       sub2
# 2   3     Garry       sub4
# 3   4  Abhishek       sub6
# 4   5     Ankit       sub5

# %%
df1.append([df2,df1,df2])
# Out:
#    id      Name subject_id
# 0   1    Piyush       sub1
# 1   2    Gautam       sub2
# 2   3     Garry       sub4
# 3   4  Abhishek       sub6
# 4   5     Ankit       sub5
# 0   1   Saurabh       sub2
# 1   2    Akshay       sub4
# 2   3     Rajat       sub3
# 3   4    Ankush       sub6
# 4   5       Sam       sub5
# 0   1    Piyush       sub1
# 1   2    Gautam       sub2
# 2   3     Garry       sub4
# 3   4  Abhishek       sub6
# 4   5     Ankit       sub5
# 0   1   Saurabh       sub2
# 1   2    Akshay       sub4
# 2   3     Rajat       sub3
# 3   4    Ankush       sub6
# 4   5       Sam       sub5

# %%
# !pip install quandl
# Out:
# ...
# You are using pip version 19.0.3, however version 20.1 is available.
# You should consider upgrading via the 'python -m pip install --upgrade pip' command.

# %%
import quandl
data=quandl.get("BSE/BOM539678", authtoken="CxKXkm_cPWLNvuczvzN6")
data
# Out:
#               Open    High     Low   Close     WAP  No. of Shares  \
# Date
# 2017-02-21  254.25  259.50  253.00  257.75  257.17        40544.0
# 2017-02-22  257.00  261.00  252.60  253.05  256.18        35603.0
# 2017-02-23  253.30  254.60  249.20  250.55  251.99        26262.0
# 2017-02-27  251.40  252.00  244.00  247.50  249.58        28019.0
# 2017-02-28  248.50  253.50  247.60  248.50  249.88        66735.0
# ...            ...     ...     ...     ...     ...            ...
# 2020-04-24  104.80  106.40  101.55  102.40  103.46         8824.0
# 2020-04-27  104.90  122.85  103.25  119.50  118.73       279663.0
# 2020-04-28  121.00  121.00  113.50  115.10  116.62        38402.0
# 2020-04-29  117.70  123.00  116.20  118.35  120.02        49716.0
# 2020-04-30  121.00  123.90  116.95  117.55  119.22        90144.0
#
#             No. of Trades  Total Turnover  Deliverable Quantity  \
# Date
# 2017-02-21         1048.0      10426526.0                9129.0
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 786 entries, 2017-02-21 to 2020-04-30
# Data columns (total 12 columns):
# Open                         786 non-null float64
# High                         786 non-null float64
# Low                          786 non-null float64
# Close                        786 non-null float64
# WAP                          786 non-null float64
# No. of Shares                786 non-null float64
# No. of Trades                786 non-null float64
# Total Turnover               786 non-null float64
# Deliverable Quantity         785 non-null float64
# % Deli. Qty to Traded Qty    785 non-null float64
# Spread H-L                   786 non-null float64
# Spread C-O                   786 non-null float64
# dtypes: float64(12)
# memory usage: 79.8 KB

# %% [markdown]
# ### JSON

# %%
import requests
r=requests.get('https://www.quandl.com/api/v3/datasets/BSE/BOM539678.json?api_key=CxKXkm_cPWLNvuczvzN6')
r

# %%
r.text

# %%
import json
d=json.loads(r.text)
d

# %%
d['dataset']['name']

# %%
d['dataset']['column_names']

# %%
data=d['dataset']['data']
data

# %%
df=pd.DataFrame(data,columns=d['dataset']['column_names'])
df

# %%
df=df.set_index('Date')
df
# Out:
# <Response [200]>

# %%
r
# Out:
# <Response [200]>

# %%
r.text
# Out:
# '{"dataset":{"id":35121372,"dataset_code":"BOM539678","database_code":"BSE","name":"Quick Heal Technologies Ltd EOD Prices","description":"End of Day prices and additional trading information for Quick Heal Technologies Ltd EOD Prices.","refreshed_at":"2020-05-06T14:07:55.401Z","newest_available_date":"2020-04-30","oldest_available_date":"2017-02-21","column_names":["Date","Open","High","Low","Close","WAP","No. of Shares","No. of Trades","Total Turnover","Deliverable Quantity","% Deli. Qty to Traded Qty","Spread H-L","Spread C-O"],"frequency":"daily","type":"Time Series","premium":false,"limit":null,"transform":null,"column_index":null,"start_date":"2017-02-21","end_date":"2020-04-30","data":[["2020-04-30",121.0,123.9,116.95,117.55,119.22,90144.0,2087.0,10746821.0,15069.0,16.72,6.95,-3.45],["2020-04-29",117.7,123.0,116.2,118.35,120.02,49716.0,1373.0,5967066.0,10573.0,21.27,6.8,0.65],["2020-04-28",121.0,121.0,113.5,115.1,116.62,38402.0,1759.0,4478593.0,12355.0,32.17,7.5,-5.9],["2020-0
# ...

# %%
import json
d=json.loads(r.text)
d
# Out:
# {'dataset': {'id': 35121372,
#   'dataset_code': 'BOM539678',
#   'database_code': 'BSE',
#   'name': 'Quick Heal Technologies Ltd EOD Prices',
#   'description': 'End of Day prices and additional trading information for Quick Heal Technologies Ltd EOD Prices.',
#   'refreshed_at': '2020-05-06T14:07:55.401Z',
#   'newest_available_date': '2020-04-30',
#   'oldest_available_date': '2017-02-21',
#   'column_names': ['Date',
#    'Open',
#    'High',
#    'Low',
#    'Close',
#    'WAP',
#    'No. of Shares',
#    'No. of Trades',
#    'Total Turnover',
#    'Deliverable Quantity',
#    '% Deli. Qty to Traded Qty',
#    'Spread H-L',
#    'Spread C-O'],
#   'frequency': 'daily',
#   'type': 'Time Series',
#   'premium': False,
#   'limit': None,
#   'transform': None,
#   'column_index': None,
#   'start_date': '2017-02-21',
#   'end_date': '2020-04-30',
#   'data': [['2020-04-30',
#     121.0,
#     123.9,
#     116.95,
#     117.55,
#     119.22,
#     90144.0,
#     2087.0,
# ...

# %%
d['dataset']['name']
# Out:
# 'Quick Heal Technologies Ltd EOD Prices'

# %%
d['dataset']['column_names']
# Out:
# ['Date',
#  'Open',
#  'High',
#  'Low',
#  'Close',
#  'WAP',
#  'No. of Shares',
#  'No. of Trades',
#  'Total Turnover',
#  'Deliverable Quantity',
#  '% Deli. Qty to Traded Qty',
#  'Spread H-L',
#  'Spread C-O']

# %%
data=d['dataset']['data']
data
# Out:
# [['2020-04-30',
#   121.0,
#   123.9,
#   116.95,
#   117.55,
#   119.22,
#   90144.0,
#   2087.0,
#   10746821.0,
#   15069.0,
#   16.72,
#   6.95,
#   -3.45],
#  ['2020-04-29',
#   117.7,
#   123.0,
#   116.2,
#   118.35,
#   120.02,
#   49716.0,
#   1373.0,
#   5967066.0,
#   10573.0,
#   21.27,
#   6.8,
#   0.65],
#  ['2020-04-28',
#   121.0,
#   121.0,
#   113.5,
#   115.1,
#   116.62,
#   38402.0,
#   1759.0,
#   4478593.0,
#   12355.0,
#   32.17,
#   7.5,
#   -5.9],
#  ['2020-04-27',
#   104.9,
#   122.85,
#   103.25,
#   119.5,
#   118.73,
#   279663.0,
#   8122.0,
#   33204990.0,
#   66913.0,
#   23.93,
#   19.6,
#   14.6],
#  ['2020-04-24',
#   104.8,
#   106.4,
#   101.55,
#   102.4,
#   103.46,
#   8824.0,
#   648.0,
#   912897.0,
#   4742.0,
#   53.74,
#   4.85,
#   -2.4],
#  ['2020-04-23',
#   110.45,
#   112.0,
#   105.6,
#   106.15,
#   109.65,
#   15356.0,
#   641.0,
#   1683771.0,
#   7874.0,
#   51.28,
#   6.4,
#   -4.3],
#  ['2020-04-22',
#   97.75,
#   112.0,
# ...

# %%
df=pd.DataFrame(data,columns=d['dataset']['column_names'])
df
# Out:
#            Date    Open    High     Low   Close     WAP  No. of Shares  \
# 0    2020-04-30  121.00  123.90  116.95  117.55  119.22        90144.0
# 1    2020-04-29  117.70  123.00  116.20  118.35  120.02        49716.0
# 2    2020-04-28  121.00  121.00  113.50  115.10  116.62        38402.0
# 3    2020-04-27  104.90  122.85  103.25  119.50  118.73       279663.0
# 4    2020-04-24  104.80  106.40  101.55  102.40  103.46         8824.0
# ..          ...     ...     ...     ...     ...     ...            ...
# 781  2017-02-28  248.50  253.50  247.60  248.50  249.88        66735.0
# 782  2017-02-27  251.40  252.00  244.00  247.50  249.58        28019.0
# 783  2017-02-23  253.30  254.60  249.20  250.55  251.99        26262.0
# 784  2017-02-22  257.00  261.00  252.60  253.05  256.18        35603.0
# 785  2017-02-21  254.25  259.50  253.00  257.75  257.17        40544.0
#
#      No. of Trades  Total Turnover  Deliverable Quantity  \
# ...

# %%
df=df.set_index('Date')
df
# Out:
#               Open    High     Low   Close     WAP  No. of Shares  \
# Date
# 2020-04-30  121.00  123.90  116.95  117.55  119.22        90144.0
# 2020-04-29  117.70  123.00  116.20  118.35  120.02        49716.0
# 2020-04-28  121.00  121.00  113.50  115.10  116.62        38402.0
# 2020-04-27  104.90  122.85  103.25  119.50  118.73       279663.0
# 2020-04-24  104.80  106.40  101.55  102.40  103.46         8824.0
# ...            ...     ...     ...     ...     ...            ...
# 2017-02-28  248.50  253.50  247.60  248.50  249.88        66735.0
# 2017-02-27  251.40  252.00  244.00  247.50  249.58        28019.0
# 2017-02-23  253.30  254.60  249.20  250.55  251.99        26262.0
# 2017-02-22  257.00  261.00  252.60  253.05  256.18        35603.0
# 2017-02-21  254.25  259.50  253.00  257.75  257.17        40544.0
#
#             No. of Trades  Total Turnover  Deliverable Quantity  \
# Date
# 2020-04-30         2087.0      10746821.0               15069.0
# ...
