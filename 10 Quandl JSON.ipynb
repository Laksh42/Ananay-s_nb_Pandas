# %%
import pandas as pd
import quandl
data=quandl.get("NSE/SBIN", authtoken="x8VdDXzBty3iGsaRLTVs")
data
# Out:
#               Open    High     Low    Last   Close  Total Trade Quantity  \
# Date
# 1998-03-20  275.40  278.80  273.30     NaN     NaN                   NaN
# 1998-03-23  278.45  280.90  278.45  279.95  279.95              591700.0
# 1998-03-24  282.00  288.40  280.00  282.25  284.35             4979900.0
# 1998-03-25  285.00  290.25  284.50  288.70  289.15             3632600.0
# 1998-03-26  289.00  289.00  280.10  281.75  281.70             3861750.0
# ...            ...     ...     ...     ...     ...                   ...
# 2018-12-31  297.20  298.25  295.50  295.65  295.90             9526067.0
# 2019-01-01  297.50  300.70  293.85  300.70  299.60            11837127.0
# 2019-01-02  299.10  302.50  293.10  293.80  293.90            25559853.0
# 2019-01-03  295.00  295.55  290.10  291.05  291.10            17548347.0
# 2019-01-04  292.10  299.00  291.50  297.30  297.65            19514041.0
#
#             Turnover (Lacs)
# Date
# 1998-03-20              NaN
# ...

# %%
import json
myjson='''
{
"status":"ok",
"source":"itronix",
"value":"id"
}
'''
a=json.loads(myjson)
print(a)
print (a["source"])
# Out:
# {'status': 'ok', 'source': 'itronix', 'value': 'id'}
# itronix

# %%
import requests
import json
a=requests.get('https://www.quandl.com/api/v3/datasets/NSE/SBIN.json?api_key=x8VdDXzBty3iGsaRLTVs')
b=json.loads(a.text)
my_data=b['dataset']['data']
for i in my_data:   #OPEN DATA
    print(i[1])
# Out:
# 292.1
# 295.0
# 299.1
# 297.5
# 297.2
# 293.6
# 296.7
# 292.85
# 293.5
# 293.65
# 298.35
# 294.7
# 287.85
# 289.3
# 288.5
# 290.0
# 283.75
# 268.35
# 271.0
# 277.0
# 278.0
# 282.45
# 287.95
# 286.7
# 288.8
# 289.3
# 289.4
# 284.6
# 284.1
# 285.95
# 283.45
# 285.9
# 293.5
# 285.9
# 283.85
# 280.4
# 276.3
# 283.7
# 287.0
# 288.9
# 296.1
# 286.45
# 287.9
# 283.0
# 275.0
# 267.5
# 250.0
# 252.0
# 254.5
# 260.25
# 258.0
# 266.0
# 259.7
# 273.75
# 264.6
# 264.4
# 266.0
# 268.0
# 261.6
# 268.0
# 259.75
# 271.0
# 267.95
# 273.35
# 265.5
# 266.4
# 264.5
# 274.0
# 264.0
# 272.7
# 274.2
# 275.4
# 285.0
# 288.5
# 290.1
# 284.0
# 287.35
# 290.65
# 295.9
# 298.0
# 296.5
# 306.8
# 312.5
# 307.9
# 309.3
# 306.8
# 308.05
# 304.0
# 300.6
# 306.95
# 308.3
# 304.1
# 295.0
# 293.5
# 296.7
# 296.0
# 317.65
# 312.95
# 304.05
# 309.85
# 300.6
# 294.6
# 293.0
# 294.5
# 297.0
# 289.2
# 289.5
# 275.1
# 268.0
# 267.2
# 262.0
# 259.9
# 259.4
# 260.1
# 250.7
# 257.0
# 262.1
# 261.4
# 262.65
# 263.85
# 258.2
# ...

# %%
import quandl
data=quandl.get("NSE/SBIN", authtoken="x8VdDXzBty3iGsaRLTVs")
data
# Out:
#               Open    High     Low    Last   Close  Total Trade Quantity  \
# Date
# 1998-03-20  275.40  278.80  273.30     NaN     NaN                   NaN
# 1998-03-23  278.45  280.90  278.45  279.95  279.95              591700.0
# 1998-03-24  282.00  288.40  280.00  282.25  284.35             4979900.0
# 1998-03-25  285.00  290.25  284.50  288.70  289.15             3632600.0
# 1998-03-26  289.00  289.00  280.10  281.75  281.70             3861750.0
# ...            ...     ...     ...     ...     ...                   ...
# 2018-12-31  297.20  298.25  295.50  295.65  295.90             9526067.0
# 2019-01-01  297.50  300.70  293.85  300.70  299.60            11837127.0
# 2019-01-02  299.10  302.50  293.10  293.80  293.90            25559853.0
# 2019-01-03  295.00  295.55  290.10  291.05  291.10            17548347.0
# 2019-01-04  292.10  299.00  291.50  297.30  297.65            19514041.0
#
#             Turnover (Lacs)
# Date
# 1998-03-20              NaN
# ...

# %%
import requests
import json
a=requests.get("https://www.quandl.com/api/v3/datasets/NSE/SBIN.json?api_key=x8VdDXzBty3iGsaRLTVs")
b=json.loads(a.text)
data=b['dataset']['data']
for i in data:
    print(i[1])
# Out:
# 292.1
# 295.0
# 299.1
# 297.5
# 297.2
# 293.6
# 296.7
# 292.85
# 293.5
# 293.65
# 298.35
# 294.7
# 287.85
# 289.3
# 288.5
# 290.0
# 283.75
# 268.35
# 271.0
# 277.0
# 278.0
# 282.45
# 287.95
# 286.7
# 288.8
# 289.3
# 289.4
# 284.6
# 284.1
# 285.95
# 283.45
# 285.9
# 293.5
# 285.9
# 283.85
# 280.4
# 276.3
# 283.7
# 287.0
# 288.9
# 296.1
# 286.45
# 287.9
# 283.0
# 275.0
# 267.5
# 250.0
# 252.0
# 254.5
# 260.25
# 258.0
# 266.0
# 259.7
# 273.75
# 264.6
# 264.4
# 266.0
# 268.0
# 261.6
# 268.0
# 259.75
# 271.0
# 267.95
# 273.35
# 265.5
# 266.4
# 264.5
# 274.0
# 264.0
# 272.7
# 274.2
# 275.4
# 285.0
# 288.5
# 290.1
# 284.0
# 287.35
# 290.65
# 295.9
# 298.0
# 296.5
# 306.8
# 312.5
# 307.9
# 309.3
# 306.8
# 308.05
# 304.0
# 300.6
# 306.95
# 308.3
# 304.1
# 295.0
# 293.5
# 296.7
# 296.0
# 317.65
# 312.95
# 304.05
# 309.85
# 300.6
# 294.6
# 293.0
# 294.5
# 297.0
# 289.2
# 289.5
# 275.1
# 268.0
# 267.2
# 262.0
# 259.9
# 259.4
# 260.1
# 250.7
# 257.0
# 262.1
# 261.4
# 262.65
# 263.85
# 258.2
# ...

# %%
data
# Out:
# [['2019-01-04', 292.1, 299.0, 291.5, 297.3, 297.65, 19514041.0, 57796.86],
#  ['2019-01-03', 295.0, 295.55, 290.1, 291.05, 291.1, 17548347.0, 51393.24],
#  ['2019-01-02', 299.1, 302.5, 293.1, 293.8, 293.9, 25559853.0, 76220.1],
#  ['2019-01-01', 297.5, 300.7, 293.85, 300.7, 299.6, 11837127.0, 35128.77],
#  ['2018-12-31', 297.2, 298.25, 295.5, 295.65, 295.9, 9526067.0, 28244.43],
#  ['2018-12-28', 293.6, 297.1, 293.55, 294.45, 294.8, 12876558.0, 38041.1],
#  ['2018-12-27', 296.7, 297.6, 291.5, 293.3, 292.15, 15304564.0, 45000.7],
#  ['2018-12-26', 292.85, 295.0, 287.15, 294.55, 294.15, 12684324.0, 36894.54],
#  ['2018-12-24', 293.5, 295.0, 290.15, 293.5, 293.05, 12048877.0, 35254.92],
#  ['2018-12-21', 293.65, 296.5, 290.8, 292.0, 291.9, 15777301.0, 46262.86],
#  ['2018-12-20', 298.35, 301.65, 293.15, 294.0, 294.05, 19222232.0, 57239.61],
#  ['2018-12-19', 294.7, 302.0, 294.7, 299.5, 300.7, 26124125.0, 78168.99],
# ...

# %%
import requests
import pandas as pd
import json
r=requests.get('https://www.quandl.com/api/v3/datasets/BSE/BOM539678.json?api_key=CxKXkm_cPWLNvuczvzN6')
d=json.loads(r.text)
df=pd.DataFrame(d['dataset']['data'],columns=d['dataset']['column_names'])
df=df.set_index('Date')
df
# Out:
#               Open    High     Low   Close     WAP  No. of Shares  \
# Date
# 2020-04-30  121.00  123.90  116.95  117.55  119.22        90144.0
# 2020-04-29  117.70  123.00  116.20  118.35  120.02        49716.0
# 2020-04-28  121.00  121.00  113.50  115.10  116.62        38402.0
# 2020-04-27  104.90  122.85  103.25  119.50  118.73       279663.0
# 2020-04-24  104.80  106.40  101.55  102.40  103.46         8824.0
# ...            ...     ...     ...     ...     ...            ...
# 2017-02-28  248.50  253.50  247.60  248.50  249.88        66735.0
# 2017-02-27  251.40  252.00  244.00  247.50  249.58        28019.0
# 2017-02-23  253.30  254.60  249.20  250.55  251.99        26262.0
# 2017-02-22  257.00  261.00  252.60  253.05  256.18        35603.0
# 2017-02-21  254.25  259.50  253.00  257.75  257.17        40544.0
#
#             No. of Trades  Total Turnover  Deliverable Quantity  \
# Date
# 2020-04-30         2087.0      10746821.0               15069.0
# ...
